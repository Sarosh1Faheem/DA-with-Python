# %% [markdown]
# 1. Write your small bio using variables and print it using print function

# %%
name = "M.Sarosh Faheem"
age = 30
city = "Karachi"
Qualification = "Bachelor's in Business Administration"
Occupation = ["MarCom Technologist",
               "SAP S/4HANA MM | SD Consultant",
               "AI Automation Engineer",
               "STEM/Robotics Instructor",
               "ECommerce Specilist",
               "Business Acumen"
               ]
Experience = "5-6 Years of Experience as a whole"
fields = "Business + IT"

print("My name is", name)
print("I am", age, "years old.")
print("I live in", city)
print("My qualification is", Qualification)
print("I have diverse experience, I'm a", ", ".join(Occupation))
print("I've,", Experience)
print("I am specialized in,", fields)
# Out:
# My name is M.Sarosh Faheem
# I am 30 years old.
# I live in Karachi
# My qualification is Bachelor's in Business Administration
# I have diverse experience, I'm a MarCom Technologist, SAP S/4HANA MM | SD Consultant, AI Automation Engineer, STEM/Robotics Instructor, ECommerce Specilist, Business Acumen
# I've, 5-6 Years of Experience as a whole
# I am specialized in, Business + IT

# %% [markdown]
# 2. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
name = "Muhammad Sarosh Faheem"
fathername = "Faheem-ul-Haque"
dob = "18th-May/1996"
print("Name: %s\nFather's Name: %s\n Date of Birth: %s" % (name, fathername, dob))
# Out:
# Name: Muhammad Sarosh Faheem
# Father's Name: Faheem-ul-Haque
#  Date of Birth: 18th-May/1996

# %% [markdown]
# 3. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
eng = 87
isl = 85
math = 90
total_marks = 300
obt_marks = eng + isl + math
print("Marks Obtained in English:", eng)
print("Marks Obtained in Islamiat:", isl)
print("Marks Obtained in Mathematics:", math)
print("Total Marks Obtained:", obt_marks)
print("Total Marks:", total_marks)
print("Percentage:", (obt_marks / total_marks) * 100, "%")
# Out:
# Marks Obtained in English: 87
# Marks Obtained in Islamiat: 85
# Marks Obtained in Mathematics: 90
# Total Marks Obtained: 262
# Total Marks: 300
# Percentage: 87.33333333333333 %

# %% [markdown]
# 4. Take the radius of a circle from a variable and calculate its Area and Circumference (use `pi = 3.14159`)

# %%
pi = 3.14159
radius = float(input("Enter the radius of the circle: "))

area = pi * (radius ** 2)
circumference = 2 * pi * radius

print("Your Radius is", radius)
print("Area of Circle:", area)
print("Circumference of Circle:", circumference)
# Out:
# Your Radius is 500.0
# Area of Circle: 785397.5
# Circumference of Circle: 3141.5899999999997

# %% [markdown]
# 5. Take the price of an item and a discount percentage in variables, then calculate and print the discount amount and the final price after discount

# %%
itemprice = 5500
discountrate = 20

discountedprice = itemprice * discountrate / 100
finalprice = itemprice - discountedprice

print(f"The price of an Airpod is {itemprice}")
print(f"The Discount going on upon Airpod is {discountrate}%")
print(f"After '{discountrate}% of discount' on '{itemprice}' of 'airpod' which is {discountedprice} for you will be now '{finalprice}'")
# Out:
# The price of an Airpod is 5500
# The Discount going on upon Airpod is 20%
# After '20% of discount' on '5500' of 'airpod' which is 1100.0 for you will be now '4400.0'

# %% [markdown]
# 6. A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
salary = float(input("Enter your Salary: "))
years = float(input("Enter year of service you have provided: "))

print(f"Based upon your Salary which is {salary} and years of services which is {years} years")
if years >= 5:
    bonus = salary * 0.05
    print(f"'Congratulation!, You've get an appraisal of {bonus}'")
else:
    print("'You are not applicable for the Bonus right now'")
# Out:
# Based upon your Salary which is 25000.0 and years of services which is 6.0 years
# 'Congratulation!, You've get an appraisal of 1250.0'

# %% [markdown]
# 7. Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are elgible for vote")
else:
    print("Not elibile for vote, Try again next year")
# Out:
# Not elibile for vote, Try again next year

# %% [markdown]
# 8. Write a program to check whether a number entered by user is even or odd.

# %%
number = int(input("Enter a Number: "))

if number % 2 == 0:
    print("Number is Even")
else:
    print("Number is Odd")
# Out:
# Number is Odd

# %% [markdown]
# 9. Write a program to check whether a number is divisible by 9 or not.
# Show Answer

# %%
number = int(input("Enter a number"))

if number % 9 == 0:
    print("Number is divisible by 9")
else:
    print("Number is not divisible by 9")
# Out:
# Number is not divisible by 9

# %% [markdown]
# 10) Write a program to display the last digit of a number.

# %%
number = int(input("Enter a number: "))

print(number)
last_digit = abs(number) % 10
print("Last digit of the number is:", last_digit)
# Out:
# 35
# Last digit of the number is: 5

# %% [markdown]
# ## OOP

# %%
class BankAccount:
    """A simple bank account."""

    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if amount > self.balance:
            return "Insufficient funds."
        self.balance -= amount
        return f"Withdrawn: {amount}"

    def summary(self):
        return f"{self.owner}: ${self.balance:,.2f}"

# %%
alice = BankAccount("Alice", 5000)
bob   = BankAccount("Bob")           # balance defaults to 0

alice.deposit(1500)
bob.deposit(800)
print(alice.withdraw(200))
print(alice.summary())
print(bob.summary())
# Out:
# Withdrawn: 200
# Alice: $6,300.00
# Bob: $800.00

# %%
class Person:
    def __init__(self, name, age, password):
        self.name      = name       # public   — anyone can read or change
        self._age      = age        # protected — intended for internal use
        self.__password = password  # private   — name mangled by Python

    def get_age(self):
        return self._age            # controlled access through a method

    def check_password(self, attempt):
        return attempt == self.__password


p = Person("Alice", 30, "secret123")

print(p.name)          # ✓ Public — works fine
print(p._age)          # ✓ Works, but you shouldn't do this outside the class
print(p.get_age())     # ✓ Correct way to access protected data
print(p.check_password("secret123"))
# Out:
# Alice
# 30
# 30
# True

# %%
print(p._Person__password)
# Out:
# secret123

# %% [markdown]
# ## File Handling

# %% [markdown]
# ### Reading Files

# %%
file = open("Files\\report.txt", "r")

# %%
with open("Files\\report.txt", "r") as file:
    content = file.read()

print(content)
# Out:
# Pipeline run: complete
# Records processed: 9500
# Errors: 0

# %%
# Read entire file as one string
with open("Files\\report.txt", "r") as f:
    content = f.read()
    print(content)
# Out:
# Pipeline run: complete
# Records processed: 9500
# Errors: 0

# %%
# Read one line at a time
with open("Files\\report.txt", "r") as f:
    first_line = f.readline()
    print(first_line)
# Out:
# Pipeline run: complete

# %%
# Read all lines into a list
with open("Files\\report.txt", "r") as f:
    lines = f.readlines()
    print(lines)
# Out:
# ['Pipeline run: complete\n', 'Records processed: 9500\n', 'Errors: 0\n']

# %%
with open("Files\\report.txt", "r") as f:
    for line in f:
        print(line.strip())
# Out:
# Pipeline run: complete
# Records processed: 9500
# Errors: 0

# %% [markdown]
# ### Writing Files

# %%
with open("Files\\report.txt", "w") as f:
    f.write("Pipeline run: complete\n")
    f.write("Records processed: 9500\n")
    f.write("Errors: 0\n")

# %%
with open("Files\\report.txt", "r") as f:
    print(f.read())
# Out:
# Pipeline run: complete
# Records processed: 9500
# Errors: 0

# %% [markdown]
# ### Apend Text in File

# %%
with open("Files\\report.txt", "a") as f:
    f.write("Next run scheduled: 02:00 UTC\n")

# %%
with open("Files\\report.txt", "r") as f:
    print(f.read())
# Out:
# Pipeline run: complete
# Records processed: 9500
# Errors: 0
# Next run scheduled: 02:00 UTC

# %% [markdown]
# #### Writing Multiple Lines at Once

# %%
lines = [
    "Region: Asia Pacific\n",
    "Status: Active\n",
    "Clients: 14\n"
]

with open("Files\\report.txt", "w") as f:
    f.writelines(lines)

# %%
with open("Files\\report.txt", "r") as f:
    print(f.read())
# Out:
# Region: Asia Pacific
# Status: Active
# Clients: 14

# %% [markdown]
# ### CSV

# %%
import csv

# %%
with open("Files\\employees.csv", "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        print(row["name"], "—", row["department"])
# Out:
# Alice — Engineering
# Bob — Finance
# Carol — Engineering

# %%
with open("Files\\employees.csv", "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        print(dict(row))
        break   # just the first row
# Out:
# {'\ufeffid': '1', 'name': 'Alice', 'department': 'Engineering', 'status': 'active'}

# %%
with open("Files\\employees.csv", "r") as f:
    reader = csv.reader(f)
    next(reader)   # skip header row
    for row in reader:
        print(row[1], row[2])   # name, department
# Out:
# Alice Engineering
# Bob Finance
# Carol Engineering

# %%
records = [
    {"id": 1, "name": "Alice", "department": "Engineering", "status": "active"},
    {"id": 2, "name": "Bob",   "department": "Finance",     "status": "active"},
]

with open("output.csv", "w", newline="") as f:
    fieldnames = ["id", "name", "department", "status"]
    writer = csv.DictWriter(f, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerows(records)

# %% [markdown]
# ### JSON

# %%
import json

# %%
response = '{"status": "ok", "records": 4200, "errors": null}'
data = json.loads(response)

print(type(data))
print(data["status"])
print(data["records"])
print(data["errors"])
# Out:
# <class 'dict'>
# ok
# 4200
# None

# %%
result = {
    "pipeline": "daily_load",
    "rows_loaded": 9500,
    "success": True
}

json_string = json.dumps(result)
print(json_string)
print(type(json_string))
# Out:
# {"pipeline": "daily_load", "rows_loaded": 9500, "success": true}
# <class 'str'>

# %%
print(json.dumps(result, indent=4))
# Out:
# {
#     "pipeline": "daily_load",
#     "rows_loaded": 9500,
#     "success": true
# }

# %% [markdown]
# ## Error Handling

# %%
records = [100, 200, 300]
print(records[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[47], line 2
#       1 records = [100, 200, 300]
# ----> 2 print(records[3])
#
# IndexError: list index out of range

# %% [markdown]
# ### Try & Except

# %%
try:
    result = 100 / 0
except:
    print("Something went wrong.")
# Out:
# Something went wrong.

# %%
value = "forty-two"

try:
    number = int(value)
    print(f"Converted: {number}")
except ValueError:
    print(f"Could not convert '{value}' to an integer.")
# Out:
# Could not convert 'forty-two' to an integer.

# %% [markdown]
# 1. ValueError
# 2. TypeError
# 3. KeyError
# 4. IndexError
# 5. FileNotFoundError6.
# 6. ZeroDivisionError
# 7. AttributeError
# 8. ImportError

# %%
def convert_record(value):
    try:
        return int(value)
    except ValueError:
        print(f"Bad value: '{value}' is not a number.")
        return None
    except TypeError:
        print(f"Bad type: expected a string, got {type(value).__name__}.")
        return None

print(convert_record("250"))
print(convert_record("abc"))
print(convert_record(None))
# Out:
# 250
# Bad value: 'abc' is not a number.
# None
# Bad type: expected a string, got NoneType.
# None

# %%
try:
    result = int(value) / count
except (ValueError, ZeroDivisionError) as e:
    print(f"Could not calculate result: {e}")
# Out:
# Could not calculate result: invalid literal for int() with base 10: 'forty-two'

# %% [markdown]
# ### Else and Finally

# %%
filename = "report.txt"

try:
    with open(filename, "r") as f:
        content = f.read()
except FileNotFoundError:
    print(f"File not found: {filename}")
else:
    print(f"File loaded successfully — {len(content)} characters.")
# Out:
# File not found: report.txt

# %%
def load_config(path):
    print("Opening config...")
    try:
        with open(path, "r") as f:
            data = f.read()
    except FileNotFoundError:
        print("Config file missing — using defaults.")
        data = "{}"
    finally:
        print("Config load attempt complete.")
    return data

load_config("settings.json")
# Out:
# Opening config...
# Config file missing — using defaults.
# Config load attempt complete.
# '{}'

# %%
try:
    result = int("500")
except ValueError:
    print("Conversion failed.")
else:
    print(f"Converted successfully: {result}")
finally:
    print("Conversion attempt finished.")
# Out:
# Converted successfully: 500
# Conversion attempt finished.

# %% [markdown]
# ### Raising Exceptions

# %%
def set_batch_size(n):
    if n <= 0:
        raise ValueError(f"Batch size must be positive. Got: {n}")
    return n

set_batch_size(100)   # works fine
set_batch_size(-5)    # raises immediately
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 7
#       3         raise ValueError(f"Batch size must be positive. Got: {n}")
#       4     return n
#       5
#       6 set_batch_size(100)   # works fine
# ----> 7 set_batch_size(-5)    # raises immediately
#
# Cell In[55], line 3, in set_batch_size(n)
#       1 def set_batch_size(n):
#       2     if n <= 0:
# ----> 3         raise ValueError(f"Batch size must be positive. Got: {n}")
#       4     return n
#
# ValueError: Batch size must be positive. Got: -5

# %%
def load_record(data, key):
    if key not in data:
        raise KeyError(f"Required field '{key}' is missing from record.")
    return data[key]

record = {"name": "Alice", "status": "active"}
print(load_record(record, "name"))
print(load_record(record, "email"))
# Out:
# Alice
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 8
#       4     return data[key]
#       5
#       6 record = {"name": "Alice", "status": "active"}
#       7 print(load_record(record, "name"))
# ----> 8 print(load_record(record, "email"))
#
# Cell In[56], line 3, in load_record(data, key)
#       1 def load_record(data, key):
#       2     if key not in data:
# ----> 3         raise KeyError(f"Required field '{key}' is missing from record.")
#       4     return data[key]
#
# KeyError: "Required field 'email' is missing from record."

# %% [markdown]
# ### Custom Exception

# %%
class ValidationError(Exception):
    """Raised when a data record fails validation."""
    pass

class PipelineError(Exception):
    """Raised when a pipeline step fails unrecoverably."""
    pass


def validate_row(row):
    if not row.get("id"):
        raise ValidationError(f"Record is missing required field 'id': {row}")
    if row["id"] < 0:
        raise ValidationError(f"Record has invalid id: {row['id']}")
    return True


try:
    validate_row({"name": "Alice", "status": "active"})
except ValidationError as e:
    print(f"Validation failed: {e}")
# Out:
# Validation failed: Record is missing required field 'id': {'name': 'Alice', 'status': 'active'}

# %%
import csv

class ValidationError(Exception):
    pass


def validate_and_parse(row):
    """Parse and validate a single CSV row. Raises ValidationError on bad data."""
    required = ["id", "name", "contract_value", "status"]
    for field in required:
        if field not in row:
            raise ValidationError(f"Missing field: '{field}'")

    try:
        row["id"] = int(row["id"])
        row["contract_value"] = float(row["contract_value"])
    except ValueError as e:
        raise ValidationError(f"Type conversion failed: {e}")

    if row["status"] not in ("active", "inactive"):
        raise ValidationError(f"Invalid status: '{row['status']}'")

    return row


def load_clients(filepath):
    """Load and validate a CSV of client records."""
    valid   = []
    invalid = []

    try:
        f = open(filepath, "r")
    except FileNotFoundError:
        print(f"Error: file not found — {filepath}")
        return [], []

    with f:
        reader = csv.DictReader(f)
        for i, row in enumerate(reader, start=1):
            try:
                parsed = validate_and_parse(row)
                valid.append(parsed)
            except ValidationError as e:
                invalid.append({"row": i, "reason": str(e), "data": dict(row)})

    return valid, invalid


valid_records, errors = load_clients("clients.csv")

print(f"Loaded:  {len(valid_records)} valid records")
print(f"Skipped: {len(errors)} invalid records")

if errors:
    print("\nValidation errors:")
    for err in errors:
        print(f"  Row {err['row']}: {err['reason']}")
# Out:
# Error: file not found — clients.csv
# Loaded:  0 valid records
# Skipped: 0 invalid records
